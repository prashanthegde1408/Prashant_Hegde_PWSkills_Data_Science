# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework

# %% [markdown]
# Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions

# %% [markdown]
# Advantages:
#
# 1. Size of the codebase is considerably less.
# 2. for straightforward applications, high scalability
# 3. Simple to construct a rapid prototype
# 4. Route URL is simple.
# 5. There are many resources online, particularly on GitHub.
# 6. Independent framework allows for architectural and library experimentation.

# %%
##############################################################################################################################

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in  Jupyter Notebook.

# %%
from flask import Flask
from flask import request

app = Flask(__name__)

@app.route('/')
def method_name():
    return "<h1> Hello World !!! </h1>"


if __name__ == '__main__':
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.82:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![question_2.jpg](attachment:question_2.jpg)

# %%
##############################################################################################################################

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.

# %% [markdown]
# To bind a function to an URL path we use the app.route decorator.

# %% [markdown]
# In above example in question 2, the URL (“/”) is associated with the root URL.

# %%
##############################################################################################################################

# %% [markdown]
# Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”  route to show the following details:
#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999

# %%
from flask import Flask, render_template

app = Flask(__name__, template_folder='CHANGED THE FOLDER LOCATION HERE AFTER RUNNING THE PROGRAM')


@app.route('/welcome')
def method_name1():
    return "<h1> Welcome to ABC Corporation </h1>"

@app.route('/')
def method_name2():
    return render_template("index.html")


if __name__ == '__main__':
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.82:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![question_5_2.jpg](attachment:question_5_2.jpg)

# %% [markdown]
# ![question_5_1.jpg](attachment:question_5_1.jpg)

# %%
##############################################################################################################################

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the  url_for() function.

# %% [markdown]
# URL Building:
#
# To build a URL to a specific function, we can use the url_for() function. It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a variable part of the URL rule. Unknown variable parts are appended to the URL as query parameters.

# %%
from flask import url_for, Flask

app = Flask(__name__)

@app.route('/')
def index():
    return 'index'

@app.route('/login')
def login():
    return 'login'

@app.route('/user/<username>')
def profile(username):
    return f'{username}\'s profile'

with app.test_request_context():
    print(url_for('index'))
    print(url_for('login'))
    print(url_for('login', next='/'))
    print(url_for('profile', username='PWskills Data Science'))
    
    
if __name__ == '__main__':
    app.run(host = "0.0.0.0")
# Out:
# /
# /login
# /login?next=%2F
# /user/PWskills%20Data%20Science
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.82:5000/ (Press CTRL+C to quit)

# %% [markdown]
# /
#
# /login
#
# /login?next=%2F
#
# /user/PWskills%20Data%20Science

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
